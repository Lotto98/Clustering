# %%
from utility import *
from sklearn.cluster import SpectralClustering

# %% [markdown]
# PCA dataframes load

# %%
dfs,y=load_PCA_dfs(200)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %% [markdown]
# Estimator

# %%
estimator=SpectralClustering(n_jobs=-1)

# %% [markdown]
# Tuning of n_clusters hyperparameter

# %%
results,best_indexes,estimator2D=get_results(dfs,y,estimator,"n_clusters",[10])#[x for x in range(5,16)])
# Out:
# ...
# PCA_2:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
results
# Out:
# {2:    n_clusters  rand index
#  0          10    0.818382}

# %%
results[2].iloc[best_indexes[2]]
# Out:
# n_clusters    10.000000
# rand index     0.818382
# Name: 0, dtype: float64

# %% [markdown]
# 2D PCA plot

# %%
labels = estimator2D.labels_

plot_clustering(dfs[2],labels)
